# %%
# This is an example snippet!
# To create your own, add a new snippet block to the
# snippets.json file in your jupyter nbextensions directory:
# /nbextensions/snippets/snippets.json
import this

# %% [markdown]
# # 문자열 메소드 활용하기

# %% [markdown]
# ## 변형
#
# ### `.capitalize()`, `.title()`, `.upper()`
#
# 1. `.capitalize()` : 앞글자를 대문자로 만들어 반환합니다.
#
# 2. `.title()` : 어포스트로피나 공백 이후를 대문자로 만들어 반환합니다.
#
# 3. `.upper()` : 모두 대문자로 만들어 반환합니다.

# %%
a = 'hI! Everyone, I\'m kim'
# 아래에 코드를 작성하세요.
a.capitalize()
# a.title()
# a.upper() # 원본을 직접 변형 시키는 것이 아니라 변형된 값만 반환

# %% [markdown]
# ### `.lower()`, `.swapcase()`
#
# `.lower()` : 모두 소문자로 만들어 반환합니다.
#
# `.swapcase()` : 대 <-> 소문자로 변경하여 반환합니다.

# %%
a = 'hI! Everyone, I\'m kim'
# 아래에 코드를 작성하세요.
# a.lower()
a.swapcase()

# %% [markdown]
# ### `.join(iterable)`
#
# 특정한 문자열로 만들어 반환합니다.
#
# Iterable 을 해당 문자열을 separator 로 합쳐서 문자열로 반환합니다.
#
# > `iterable`
# >
# > 각각의 요소를 하나씩 반환할 수 있는 객체를 말한다. List와 Tuple, Dictionary와 Set 등이 여기에 속한다.

# %%
# 아래에 코드를 작성하세요.
'!'.join(' 배고파')

# %%
a = ['hi', 'hello']
' '.join(a)

# %% [markdown]
# ### `.replace(old, new[, count])`
#
# 바꿀 대상 글자를 새로운 글자로 바꿔서 반환합니다.
#
# count를 지정하면 해당 개수만큼만 시행합니다.

# %%
# 아래에 코드를 작성하세요.
'yay!'.replace('a', '_')

# %%
'woooooooowoooo'.replace('o', '_', 2)

# %% [markdown]
# ### 글씨 제거 (`.strip([chars])`)
#
# 특정한 문자들을 지정하면,  양쪽을 제거하거나 왼쪽을 제거하거나(lstrip) 오른쪽을 제거합니다(rstrip)
#
# 지정하지 않으면 공백을 제거합니다.

# %%
# 아래에 코드를 작성하세요.
'      \n oh!\n'.strip()
# Out:
# 'oh!'

# %%
'     oh!     '.lstrip()
# Out:
# 'oh!     '

# %%
'hehehehehehihihihihihihihi'.rstrip('hi')
# Out:
# 'hehehehehe'

# %% [markdown]
# ## 탐색 및 검증
#
# ### `.find(x)` : x의 첫 번째 위치를 반환합니다. 없으면, -1을 반환합니다.

# %%
# 아래에 코드를 작성하세요.
'apple'.find('p')
'apple'.find('o')

# %% [markdown]
# ### `.index(x)` : x의 첫번째 위치를 반환합니다. 없으면, 오류가 발생합니다.

# %%
# 아래에 코드를 작성하세요.
'apple'.index('p')

# %%
'apple'.index('o')

# %% [markdown]
# ## `.split()`
#
# 문자열을 특정한 단위로 나누어 리스트로 반환합니다.

# %%
# 아래에 코드를 작성하세요.

# %%
'a_b_c'.split('_')
# Out:
# ['a', 'b', 'c']

# %%
inputs = input().split()
print(inputs)
# Out:
# ajskdjka ajskdl
# ['ajskdjka', 'ajskdl']

# %% [markdown]
# ## 다양한 확인 메소드 : 참/거짓 반환
# ```
# .isalpha(), .isdecimal(), .isdigit(), .isnumeric(), .isspace(), .isupper(), .istitle(), .islower()
# ```
#
# ```python
# dir('string')
# ```

# %%
'string'.isalpha()

# %%
'string'.isdecimal()

# %%
'string'.isdigit()

# %%
'string'.isnumeric()

# %% [markdown]
# +-------------+-----------+-------------+----------------------------------+
# | isdecimal() | isdigit() | isnumeric() |          Example                 |
# +-------------+-----------+-------------+----------------------------------+
# |    True     |    True   |    True     | "038", "੦੩੮", "０３８"           |
# |  False      |    True   |    True     | "⁰³⁸", "🄀⒊⒏", "⓪③⑧"          |
# |  False      |  False    |    True     | "↉⅛⅘", "ⅠⅢⅧ", "⑩⑬㊿", "壹貳參"  |
# |  False      |  False    |  False      | "abc", "38.0", "-38"             |
# +-------------+-----------+-------------+----------------------------------+

# %% [markdown]
# # 리스트 메소드 활용하기
#
# ## 값 추가 및 삭제
#
# ### `.append(x)`
#
# 리스트에 값을 추가할 수 있습니다.

# %%
# 카페 리스트를 만들어봅시다.

# %%
cafe = ['startbucks', 'tomntomns', 'hollys']

# %%
# 값을 추가해봅시다.

# %%
cafe.append('caffebene')
print(cafe)

# %%
# 어렵게 넣어보도록 해봅시다.
cafe[len(cafe):] = ['ediya']
print(cafe)

# %% [markdown]
# ### `.extend(iterable)`
#
# 리스트에 iterable(list, range, tuple, string*유의*) 값을 붙일 수가 있습니다.
# 요소 하나하나 넣을 수 있다.

# %%
# 앞서 만든 리스트에 추가해봅시다.

# %%
cafe.extend(['droptop', '뺵다방'])
print(cafe)

# %%
# 앞서 배운 list concatenate와 동일합니다.
cafe += ['mccafe','burgerkin']
print(cafe)

# %%
# append와 비교해봅시다.
cafe.append(['append cafe'])
print(cafe)
print('-----')

cafe.extend(['extend cafe'])
print(cafe)
print('-----')

cafe.extend('extend string')
print(cafe)

# %% [markdown]
# extend는 요소 하나하나 들어간다.

# %% [markdown]
# ### `.insert(i, x)`
#
# 정해진 위치 `i`에 값을 추가합니다.

# %%
# 앞서 만든 리스트의 가장 앞에 'hi'를 넣어봅시다.

# %%
cafe.insert(0, 'hi')
print(cafe)

# %%
# 앞서 만든 리스트의 가장 뒤에 'bye'를 넣어봅시다
cafe.insert(len(cafe), 'bye')
print(cafe)

# %%
# 길이를 넘어서는 인덱스는 무조건 마지막에 하나만 붙습니다.

# %%
cafe.insert(len(cafe)+100, '!')
print(cafe)

# %% [markdown]
# ### `.remove(x)`
#
# 리스트에서 값이 x인 것을 삭제합니다.

# %%
# remove를 사용해봅시다.

# %%
numbers = [1, 2, 3, 1, 2]

# %%
# 중복된 값 1을 삭제 해봅시다.

# %%
numbers.remove(1)
print(numbers)

# %%
# 한번 더 삭제해봅시다.

# %%
numbers.remove(1)
print(numbers)

# %%
# remove는 값이 없으면 오류가 발생합니다. 확인해봅시다.

# %%
numbers.remove(10)

# %% [markdown]
# ### `.pop(i)`
#
# 정해진 위치 `i`에 있는 값을 삭제하며, 그 항목을 반환합니다.
#
# `i`가 지정되지 않으면 마지막 항목을 삭제하고 되돌려줍니다.

# %%
# pop을 사용해봅시다.
a = [1, 2, 3, 4, 5, 6]

# %%
# 가장 앞에 있는 것을 삭제해봅시다. return도 확인해보세요.

# %%
print(a.pop(0))

# %%
print(a)

# %%
# 값이 return이 된다는 것은 별도의 변수에 저장할 수 있다는 것입니다.

# %%
deleted_value = a.pop()
print(f'{deleted_value}가 삭제되어 {a}이 되었습니다.')

# %% [markdown]
# ## 탐색 및 정렬

# %% [markdown]
# ### `.index(x)`
#
# x 값을 찾아 해당 index 값을 반환합니다.

# %%
# index를 사용해봅시다.
a = [1, 2, 3, 4, 5]

# %%
a.index(3) # 3번째 항목에 있다.

# %%
#.index()는 해당 값이 없을 시 valueerror 가 발생합니다.
a.index(100)

# %% [markdown]
# ### `.count(x)`
#
# 원하는 값의 갯수를 확인할 수 있습니다.

# %%
# count를 사용해봅시다.
a = [1, 2, 5, 1, 5, 1]

# %%
# 따라서 원하는 값을 모두 삭제하려면 다음과 같이 할 수 있습니다.

# %%
a = [1, 2, 5, 1, 5, 1]
target_value = 1
for i in range(a.count(target_value)):
    a.remove(target_value)

# %%
# 모두 삭제되었는지 검증해봅시다.
print(a)

# %% [markdown]
# ### `.sort()`
#
# 정렬을 합니다.
#
#
# `sorted()` 와는 다르게 **원본 list를 변형**시키고, **None**을 리턴합니다.

# %%
# sort() 를 사용해봅시다.

# %%
import random
lotto = random.sample(range(1,46), 6)
print(lotto)
# Out:
# [4, 15, 39, 38, 27, 17]

# %%
lotto.sort()
print(lotto.sort())
print(lotto)

lotto.sort(reverse=True)
print(lotto)
# Out:
# None
# [4, 15, 17, 27, 38, 39]
# [39, 38, 27, 17, 15, 4]

# %% [markdown]
# ### `.reverse()`
#
# 반대로 뒤집습니다. (정렬 아님)

# %%
classroom = ['Tom', 'David', 'Justin']
classroom.reverse()
print(classroom)

# %% [markdown]
# ## 복사

# %%
# 리스트 복사를 해봅시다.
original_list = [1, 2, 3]

# %%
copy_list = original_list
print(copy_list)

# %%
# copy_list 의 값을 바꾸고 original_list를 출력해봅시다. 
copy_list[0] = 5 # 바뀝니다.
print(original_list) # Why?? ID 값 확인!

# %%
# id 값을 확인해봅시다.
copy_list is original_list
#이 말인 즉슨, original_list의 주소를 copy_list에도 똑같이 복사하여서, 같은 주소가 할당되므로 copy_list와 
#                      original_list가 같다고 생각하면 된다.

# %%
# 숫자를 확인해봅시다. #b의 객체에 새로운 값이 부여되면, 새로운 id 위치에 저장되어 새로운 변수가 된다. a에는 영향 x

# %%
a = 20005
b = a
a is b
# b = 30005
# print(a)

# %%
# 딕셔너리도 확인해봅시다.

# %%
lunch = {'김밥천국': '치즈라면', '김가네':'제육볶음'}
dinner = lunch

dinner['김밥천국'] = '참치김밥'
print(lunch)

# %% [markdown]
# ### copy
# > pythontutor 를 활용하여 자세하게 알아봅시다.
#
# * 파이썬에서 모든 변수는 **객체의 주소**를 가지고 있을 뿐입니다.
#
# ```
# num = [1, 2, 3]
# ```
#
# * 위와 같이 변수를 생성하면 hong이라는 객체를 생성하고, 변수에는 객체의 주소가 저장됩니다.
#
# * 변경가능한(mutable) 자료형과 변경불가능한(immutable) 자료형은 서로 다르게 동작합니다.
#
# 따라서, 복사를 하고 싶을 때에는 다음과 같이 해야합니다.

# %%
# 리스트를 복사해봅시다.

# %%
a = [1, 2, 3]
b = a[:]

b[0] = 5
print(a)

# %% [markdown]
# * 하지만, 이렇게 하는 것도 일부 상황에만 서로 `다른 얕은 복사(shallow copy)`입니다.

# %%
#리스트 안에 리스트가 있을 때 문제가 발생

# %%
# 2차원 배열을 복사해봅시다.
a = [1, 2, [1, 2]]
b = a[:]

b[2][0] = 100 # 안에 있는 요소들은 같은 곳을 바라 보고 있으므로(ID가 같으므로) 값이 바뀐다. 
print(a)

# %% [markdown]
# * 만일 중첩된 상황에서 복사를 하고 싶다면, `깊은 복사(deep copy)`를 해야합니다.
#
# * 즉, 내부에 있는 모든 객체까지 새롭게 값이 변경됩니다.

# %%
# 깊은 복사를 사용해봅시다.
# 모듈필요

# %%
import copy
a = [1, 2, [1, 2]]
b = copy.deepcopy(a)
b[2][0]
print(a)

# %% [markdown]
# ## `.clear()`
#
# 리스트의 모든 항목을 삭제합니다.

# %%
# clear를 사용해봅시다.
numbers = list(range(1, 100))
print(numbers)
numbers.clear()
print(numbers)

# %% [markdown]
# # List Comprehension
# list comprehension은 온리스트 안에 식, for 문을 지정합니다.
# 여러줄의 코드를 한 줄로 줄일 수 있습니다.
#
# List를 만들 수 있는 간단한 방법이 있습니다.
#
# ```python
# [식 for 변수 in iterable]
#
# list(식 for 변수 in iterable)
#
#
# ```

# %% [markdown]
# ### 세제곱리스트
#
# > 다음의 리스트를 만들어보세요.
#
# - 1~10까지의 숫자로 만든 세제곱 담긴 리스트 `cubic_list`

# %%
a = range(1, 11)

# %%
# 기존의 방법
cubic_list = []
for i in range(1, 11):
    cubic_list.append(i**3)
print(cubic_list)

# %%
# List Comprehension

# %%
cubuc_list = [x**3 for x in range(1,11)]
print(cubic_list)

# %% [markdown]
# 식이 앞으로 오고 조건문이 뒤로, 작동 순서는 뒤에서부터 앞으로

# %% [markdown]
# ## List Comprehension + 조건문
#
#  [식 for 변수 in iterable if 조건식]

# %% [markdown]
# ### 짝수리스트
# > 다음의 리스트를 만들어보세요.
#
# - 1~10까지의 숫자중 짝수만 담긴 리스트 `even_list`
# - 여러개의 `for` 혹은 `if`문을 중첩적으로 사용 가능합니다.

# %%
a = range(1, 11)

# %%
# 기존의 방법

# %%
even_list = []
for i in range(1, 11):
    if i % 2 == 0:
        even_list.append(i)
        
print(even_list)

# %%
# List Comprehension
even_list = [if i % 2 == 0 for i in range(1, 11)]

# %%
even_list = [x for x in range(1, 11) if x%2==0]
print(even_list)

# %% [markdown]
# ### 곱집합
#
# > 주어진 두 list의 가능한 모든 조합을 담은 `pair` 리스트를 만들어주세요.
#
# 1. 반복문 활용
# 2. list comprehension 활용
#
#
# 이중 for문은 큰 문부터 작은문까지 써내려 가면 됩니다.
#
# ---
#
# ```python
# girls = ['jane', 'iu', 'mary']
# boys = ['justin', 'david', 'kim']
#
# 예시 출력)
#
# [('justin', 'jane'), ('justin', 'iu'), ('justin', 'mary'), ('david', 'jane'), ('david', 'iu'), ('david', 'mary'), ('kim', 'jane'), ('kim', 'iu'), ('kim', 'mary')]
# ```

# %%
girls = ['jane', 'iu', 'mary']
boys = ['justin', 'david', 'kim']

# %%
# 반복문을 활용하여 만들어주세요.

# %%
pair = []
for i in range(3):
    pair.append([boys[i]])
    for i in range(3):
        pair.append(girls[i])
    
print(pair)

# %%
pair = []
for boy in boys:
    for girl in girls:
        pair.append((boy, girl))
print(pair)

# %%
# List comprehension을 활용하여 만들어주세요.

# %%
pair = [(boy, girl) for boy in boys for girl in girls]
print(pair)

# %% [markdown]
# ### 피타고라스 정리
#
# > 주어진 조건(x < y < z < 50) 내에서 피타고라스 방정식의 해를 찾아보세요.
#
# 1. 반복문 활용
#
# 2. list comprehension 활용
#
# ```python
# 예시 출력)
# [(3, 4, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (12, 16, 20), (12, 35, 37), (15, 20, 25), (15, 36, 39), (16, 30, 34), (18, 24, 30), (20, 21, 29), (21, 28, 35), (24, 32, 40), (27, 36, 45)]
# ```

# %%
# 반복문을 활용하여 만들어주세요.

# %%
pita = []

for z in range(50):
    for y in range(50):
        for x in range(50):
            if x<y and y<z and z<50:
                if x**2 + y**2 == z**2:
                    pita.append((x, y, z))
            
print(pita)

# %%
pita = []

for x in range(50):
    for y in range(50):
        for z in range(50):
            if x<y and y<z and z<50:
                if x**2 + y**2 == z**2:
                    pita.append((x, y, z))
            
print(pita)

# %%
result = []
for x in range(1, 50):
    for y in range(x, 50):
        for z in range(y, 50):
            if x**2 + y**2 == z**2:
                result.append((x, y, z))
print(result)

# %%
# List comprehension을 활용하여 만들어주세요.

pita = [(x, y, z) for x in range(1, 50) for y in range(1, 50) for z in range(1, 50) if x<y and y<z and z<50 if x**2 + y**2 == z**2]
print(pita)

# %%
result = [(x, y , z) for x in range(1,50) for y in range(x,50) for z in range(y,50) if x**2 + y**2 == z**2]
print(result)

# %% [markdown]
# ### 모음 제거하기
#
# > 다음의 문장에서 모음(a, e, i, o, u)를 모두 제거하시오.
#
# 1. list comprehension만 사용해보세요.
#
# ```python
#     words = 'Life is too short, you need python!'
#
#     예시출력)
#     Lf s t shrt, y nd pythn!
# ```

# %%
# List comprehension을 활용하여 만들어주세요.
words = 'Life is too short, you need python!'
word = []
word.append(words)

print(word)

# %%
'Life is too short, you need python!'.strip('i')

# %%
'Life is too short, you need python!'.split()

# %%
word = ['a', 'e', 'i', 'o', 'u']
words = 'Life is too short, you need python!'

# %%
words = 'Life is too short, you need python!'
vowels = 'aeiou'

result = [x for x in words if x not in vowels]
print(result)
print(''.join(result))

# %%
result = []
for x in words:
    if x not in vowels:
        result.append(x)
        
print(''.join(result))

# %% [markdown]
# ## List Comprehension + 조건문
# ```python
# [식 for 변수 in iterable if 조건식]
#
# [식 if 조건식 else 식 for 변수 in iterable]
#
# # elif는 다음과 같이 사용해야 합니다.
# [식 if 조건식 else 식 if 조건식 else 식 for 변수 in iterable]
#
#
# ```

# %% [markdown]
# # 딕셔너리 메소드 활용

# %% [markdown]
# ## 추가 및 삭제
#
# ### `.pop(key[, default])`
#
# key가 딕셔너리에 있으면 제거하고 그 값을 돌려줍니다. 그렇지 않으면 default를 반환합니다.
#
# default가 없는 상태에서 딕셔너리에 없으면 KeyError가 발생합니다.

# %%
# pop을 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나'}

# %%
my_dict.pop('apple')
print(my_dict)

# %%
# 딕셔너리에 없으면 에러가 발생합니다
mydict.pop('melon')

# %%
# 두번째 인자로 default를 설정할 수 있습니다
my_dict.pop('melon', 0)

# %% [markdown]
# ### `.update()`
#
# 값을 제공하는 key, value로 덮어씁니다.

# %%
# update를 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}

# %%
my_dict.update(apple='사과아아아아아아아')
print(my_dict)

# %% [markdown]
# ### `.get(key[, default])`
#
# key를 통해 value를 가져옵니다.
#
# 절대로 KeyError가 발생하지 않습니다. default는 기본적으로 None입니다.

# %%
# get을 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}
my_dict['pineapple']

# %%
print(my_dict.get('pineapple'))
print(my_dict.get('apple'))
print(my_dict.get('coconut', 1))

# %% [markdown]
# ## dictionary comprehension
#
# dictionary도 comprehension을 활용하여 만들 수 있습니다.
# ```python
# {키: 값 for 키, 값 in 딕셔너리}
#
# dict(키 : 값 for 키, 값 in 딕셔너리)
#
# {키: 값 for 키,값 in 딕셔너리 if 조건식}
#
# {키: 값 if 조건식 else 키: 값 for 키, 값 in 딕셔너리}
#
# ```

# %%
# dictionary comprehension

# %%
cubic = {x: x**3 for x in range(1, 8)}
print(cubic)

# %% [markdown]
# ### dictionary comprehension 사용해보기

# %%
dusts = {'서울': 72, '대전': 82, '구미': 29, '광주': 45, '중국': 200}

# %%
part = {}
for key, value in dusts.items():
    if value > 80:
        part[key] = value

print(part)

# %%
result = {key: value for key, value in dusts.items() if value > 80}
print(result)

# %%
# 미세먼지 농도가 80 초과 지역만 뽑아 봅시다.
# 예) {'대전': 82, '중국': 200}

part = {key: value for key, value in dusts.items() if value > 80}
print(part)
print(type(value))

# %%
part = {x: y for x, y in dusts.items() if int(y) > 80}

# %%
# 미세먼지 농도가 80초과는 나쁨 80이하는 보통으로 하는 value를 가지도록 바꿔봅시다.
# 150 초과 : 매우나쁨 / 80초과 : 나쁨 / 30초과 : 보통 / 그 외 좋음

# %%
result = {}

for key, value in dusts.items():
    if value > 150:
        result[key] = '매우나쁨'
    elif value > 80:
        result[key] = '나쁨'
    elif value > 30:
        result[key] = '보통'
    else:
        result[key] = '좋음'

print(result)

# %%
result = {key: value for key, value in dusts.items() if value > 150 result[key] = '매우나쁨'}
print(result)

# %%
result = {key: '매우나쁨' if value > 150 else '보통' for key, value in dusts.items()}
print(result)

# %%
result = {key: '나쁨' if value>80 else '보통' for key, value in dusts.items()}
print(result)

# %%
# elif 도 사용할 수 있습니다.

# %%
result = {key: '매우나쁨' if value>150 else '나쁨' if value>80 else '보통' if value>30 else '좋음' for key,value in dusts.items()}
print(result)

# %% [markdown]
# # 세트 메소드 활용

# %% [markdown]
# ## 추가 및 삭제
#
# ### `.add(elem)`
# elem을 세트에 추가합니다.

# %%
# add를 사용해봅시다.
a = {'사과', '바나나', '수박'}
b = {'사과': 1, '바나나': 2, '수박': 3}

# %%
a.add('포도')
print(a)
a.add('ㅠㅗ')
a.add('포도')
print(a)
b.add('배')
print(b)

# %% [markdown]
# ### `.update(*others)`
#
# 여러가지의 값을 추가합니다.
#
# 여기서 반드시 iterable한 값을 넣어야합니다.

# %%
# update를 사용해봅시다.
a = {'사과', '바나나', '수박'}

# %%
a.update({'토마토', '토마토', '딸기'}, {'포도', '레몬', '딸기'})
print(a)

# %% [markdown]
# ### `.remove(elem)`
#
# elem을 세트에서 삭제하고, 없으면 KeyError가 발생합니다.

# %%
# remove를 사용해봅시다.
a = {'사과', '바나나', '수박'}

# %%
a.remove('사과')
print(a)

# %%
a.remove('맬론')

# %% [markdown]
# ### `.discard(elem)`
# x를 세트에서 삭제하고 없어도 에러가 발생하지 않습니다.

# %%
# discard를 사용해봅시다.
a = {"사과", "바나나", "수박"}

# %%
a.discard('바나나')
print(a)

# %%
a.discard('바나나')

# %% [markdown]
# ### `.pop()`
#
# **임의의 원소**를 제거해 반환합니다.
#
# 불변인 타입은 파이썬이 hash table이라는 것으로 만든다.
# 이 hash table에 정해진 순서가 존재합니다.
#
# 현재 파이썬 실행환경에서 set.pop()이 계속 같은 이뉴는 처음 만들어진 set 이 같은 hash table 값으로 이루어져 있기 떄문이다.
#
# 파이썬 실행환경이 바뀌어야 pop으로 나오는 인자가 바뀐다 (즉, 파이썬 실행환경이 바뀌면 만들어지는 hash table도 바뀌기 때문이다.

# %%
# pop을 사용해봅시다.
a = {'사과', '바나나', '수박', '아보카도'}

# %%
print(a.pop())

# %% [markdown]
# #  `map()`, `zip()`, `filter()`

# %% [markdown]
# ## `map(function, iterable)`
#
# * Iterable의 모든 원소에 function을 적용한 후 그 결과를 돌려줍니다.
#
# * 대표적으로 iterable한 타입 - list, dict, set, str, bytes, tuple, range
#
# * return은 `map_object` 형태로 됩니다.
#
# 많이 잘 쓰는 코드이다. 연습많이하자.

# %%
numbers = [1, 2, 3]
# 위의 코드를 문자열 '123'으로 만들어봅시다.

# %%
str(numbers)

# %%
# list comprehension

# %%
list_comprehension = [str(number) for number in numbers]
print(list_comprehension)
print(''.join(list_comprehension))

# %%
new_numbers = str(num) for num in numbers
print(new_numbers)

# %%
# map을 이용하기
new_numbers = map(str, numbers)
print(new_numbers)

# %%
print(''.join(new_numbers))

# %%
numbers = ['1', '2', '3']
# 위의 코드를 [1, 2, 3]으로 만들어봅시다.

# %%
# list comprehension
num_list = [int(num) for num in numbers]
print(num_list)

# %%
#map
num_list = list(map(int, numbers))
print(num_list)

# %%
num_list = [map(int, numbers)]
print(num_list)

# %% [markdown]
# * function은 사용자 정의 함수도 가능합니다.

# %%
# 세제곱의 결과를 나타내는 함수
def cube(num):
    return num**3


numbers = [1, 2, 3, 4, 5]

# %%
cube_list = map(cube, numbers)
print(cube_list)
print(list(cube_list))

# %% [markdown]
# ## `zip(*iterables)`
#
# * 복수 iterable한 것들을 모아준다.
#
# * 결과는 튜플의 모음으로 구성된 zip object를 반환한다.

# %%
# 예시를 봅시다.
girls = ['jane', 'iu', 'mary']
boys = ['justin', 'david', 'kim']

# %%
zip(girls, boys)
list(zip(girls, boys))

# %%
# for문으로 한 명씩 순서대로 매칭시켜봅시다.
# 예) {'jane': 'justin', 'iu': 'david', 'mary': 'kim'}

# %%
#dictionary comprehension
dict_group2 = {key: value for girl in girls}
print(dict_group2)

# %%
#결과값이 다 'kim'으로 나옴

# %%
{girl: boy for girl in girls for boy in boys}

# 이중 for문으로 key는 유일하므로 마지막 값으로 덮어씌워진다. 'kim'

# %%
{girl: boy for girl, boy in zip(girls, boys)}

# %% [markdown]
# * 아래와 같이 사용가능하다.

# %%
a = '123'
b = '456'

for digit_a, digit_b in zip(a, b):
    print(digit_a, digit_b)

# %% [markdown]
# * zip은 반드시 길이가 같을 때 사용해야한다. 가장 짧은 것을 기준으로 구성한다.

# %%
num1 = [1, 2, 3]
num2 = ['1', '2']
zip(num1, num2)
list(zip(num1, num2))

# %% [markdown]
# * 길이가 긴 것을 맞춰서 할 수도 있지만, 사용할 일이 없다.

# %%
from itertools import zip_longest
list(zip_longest(num1, num2, fillvalue=0))

# %% [markdown]
# ## `filter(function, iterable)`
#
# * iterable에서 function의 반환된 결과가 참인 것들만 구성하여 반환한다.

# %%
# 홀수인지 판단하는 함수를 작성해봅시다.
def odd(n):
    return n % 2

# %%
numbers = [1, 2, 3, 4, 5]
filter(odd, numbers)

# %%
list(filter(odd, numbers))

# %%
# 다음의 list comprehension과 동일하다.

# %%
[x for x in numbers if x % 2]

# %%
[x for x in numbers if odd(x)]

# %% [markdown]
# 1. 풀어쓰고
# 2. comprehension으로 써보고
# 3. map,filter,zip으로 활용할 수 있는 것을 판단하기
